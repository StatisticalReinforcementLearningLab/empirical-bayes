# %%
# C++ Simulation Output & Python Analysis
# This notebook walks through the changes we made to the C++ source so that it
# runs many replicates, writes average regret curves to a CSV file, and then uses
# Python to load that file and draw the corresponding plots.
